# %% [markdown]
# STAT 453: Deep Learning (Spring 2020)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2020/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss20

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Sebastian Raschka
#
# CPython 3.7.3
# IPython 7.9.0
#
# torch 1.4.0

# %% [markdown]
# - Runs on CPU or GPU (if available)

# %% [markdown]
# # Convolutional GAN That Fails

# %% [markdown]
# ## Imports

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
from torch.utils.data import DataLoader


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

# Device
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# Hyperparameters
random_seed = 42
generator_learning_rate = 0.0001
discriminator_learning_rate = 0.0001
num_epochs = 100
BATCH_SIZE = 128
LATENT_DIM = 100
IMG_SHAPE = (1, 28, 28)
IMG_SIZE = 1
for x in IMG_SHAPE:
    IMG_SIZE *= x



##########################
### MNIST DATASET
##########################

# Note transforms.ToTensor() scales input images
# to 0-1 range
train_dataset = datasets.MNIST(root='data', 
                               train=True, 
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='data', 
                              train=False, 
                              transform=transforms.ToTensor())


train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=BATCH_SIZE,
                          num_workers=4,
                          shuffle=True)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=BATCH_SIZE,
                         num_workers=4,
                         shuffle=False)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Image batch dimensions: torch.Size([128, 1, 28, 28])
# Image label dimensions: torch.Size([128])

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################

class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)
    
class Reshape1(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), 64, 7, 7)


class GAN(torch.nn.Module):

    def __init__(self):
        super(GAN, self).__init__()
        
        
        self.generator = nn.Sequential(
              
            nn.Linear(LATENT_DIM, 3136),
            nn.LeakyReLU(inplace=True),
            Reshape1(),
            
            nn.ConvTranspose2d(in_channels=64, out_channels=64, kernel_size=(2, 2), stride=(2, 2), padding=0),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(in_channels=64, out_channels=32, padding=1, kernel_size=(2, 2)),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(inplace=True),    
            
            nn.ConvTranspose2d(in_channels=32, out_channels=32, kernel_size=(2, 2), stride=(2, 2), padding=0),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=16, padding=1, kernel_size=(2, 2)),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(inplace=True),      
            
            nn.Conv2d(in_channels=16, out_channels=8, padding=1, kernel_size=(3, 3)),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(inplace=True),    
            
            nn.Conv2d(in_channels=8, out_channels=4, padding=0, kernel_size=(3, 3)),
            nn.BatchNorm2d(4),
            nn.LeakyReLU(inplace=True),    
            
            nn.Conv2d(in_channels=4, out_channels=1, padding=0, kernel_size=(2, 2)),
            nn.Tanh()
        )
        
        self.discriminator = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=8, padding=1, kernel_size=(3, 3)),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(inplace=True), 
            nn.Conv2d(in_channels=8, out_channels=8, padding=1, stride=2, kernel_size=(3, 3)),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(inplace=True),
            
            
            nn.Conv2d(in_channels=8, out_channels=16, padding=1, kernel_size=(3, 3)),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(in_channels=16, out_channels=16, padding=1, stride=2, kernel_size=(3, 3)),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(inplace=True),
            
            nn.Conv2d(in_channels=16, out_channels=32, padding=1, kernel_size=(3, 3)),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=32, padding=1, stride=2, kernel_size=(3, 3)),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(inplace=True),
            
            nn.AdaptiveAvgPool2d(1),
            Flatten(),
            nn.Linear(32, 16),
            nn.LeakyReLU(inplace=True),
            nn.BatchNorm1d(16),
            
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

            
    def generator_forward(self, z):
        img = self.generator(z)
        return img
    
    def discriminator_forward(self, img):
        pred = model.discriminator(img)
        return pred.view(-1)

# %%
torch.manual_seed(random_seed)

#del model
model = GAN()
model = model.to(device)

print(model)
# Out:
# GAN(
#   (generator): Sequential(
#     (0): Linear(in_features=100, out_features=3136, bias=True)
#     (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     (2): Reshape1()
#     (3): ConvTranspose2d(64, 64, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.01, inplace=True)
#     (6): Conv2d(64, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.01, inplace=True)
#     (9): ConvTranspose2d(32, 32, kernel_size=(2, 2), stride=(2, 2))
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.01, inplace=True)
#     (12): Conv2d(32, 16, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): LeakyReLU(negative_slope=0.01, inplace=True)
#     (15): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): LeakyReLU(negative_slope=0.01, inplace=True)
#     (18): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1))
#     (19): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): LeakyReLU(negative_slope=0.01, inplace=True)
#     (21): Conv2d(4, 1, kernel_size=(2, 2), stride=(1, 1))
#     (22): Tanh()
#   )
#   (discriminator): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#     (3): Conv2d(8, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.01, inplace=True)
#     (6): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.01, inplace=True)
#     (9): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (10): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.01, inplace=True)
#     (12): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): LeakyReLU(negative_slope=0.01, inplace=True)
#     (15): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (16): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): LeakyReLU(negative_slope=0.01, inplace=True)
#     (18): AdaptiveAvgPool2d(output_size=1)
#     (19): Flatten()
#     (20): Linear(in_features=32, out_features=16, bias=True)
#     (21): LeakyReLU(negative_slope=0.01, inplace=True)
#     (22): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): Linear(in_features=16, out_features=1, bias=True)
#     (24): Sigmoid()
#   )
# )

# %%
### ## FOR DEBUGGING

"""
outputs = []
def hook(module, input, output):
    outputs.append(output)

#for i, layer in enumerate(model.discriminator):
#    if isinstance(layer, torch.nn.modules.conv.Conv2d):
#        model.discriminator[i].register_forward_hook(hook)

for i, layer in enumerate(model.generator):
    if isinstance(layer, torch.nn.modules.conv.Conv2d):
        model.generator[i].register_forward_hook(hook)
"""
# Out:
# '\noutputs = []\ndef hook(module, input, output):\n    outputs.append(output)\n\n#for i, layer in enumerate(model.discriminator):\n#    if isinstance(layer, torch.nn.modules.conv.Conv2d):\n#        model.discriminator[i].register_forward_hook(hook)\n\nfor i, layer in enumerate(model.generator):\n    if isinstance(layer, torch.nn.modules.conv.Conv2d):\n        model.generator[i].register_forward_hook(hook)\n'

# %%
optim_gener = torch.optim.Adam(model.generator.parameters(), lr=generator_learning_rate)
optim_discr = torch.optim.Adam(model.discriminator.parameters(), lr=discriminator_learning_rate)

# %% [markdown]
# ## Training

# %%
start_time = time.time()    

discr_costs = []
gener_costs = []
for epoch in range(num_epochs):
    model = model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):

        
        # Normalize images to [-1, 1] range
        features = (features - 0.5)*2.
        features = features.view(-1, IMG_SIZE).to(device) 

        targets = targets.to(device)

        valid = torch.ones(targets.size(0)).float().to(device)
        fake = torch.zeros(targets.size(0)).float().to(device)
        

        ### FORWARD AND BACK PROP
        
        
        # --------------------------
        # Train Generator
        # --------------------------
        
        # Make new images
        z = torch.zeros((targets.size(0), LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
        generated_features = model.generator_forward(z)
        
        # Loss for fooling the discriminator
        discr_pred = model.discriminator_forward(generated_features.view(targets.size(0), 1, 28, 28))
        
        gener_loss = F.binary_cross_entropy(discr_pred, valid)
        
        optim_gener.zero_grad()
        gener_loss.backward()
        optim_gener.step()
        
        # --------------------------
        # Train Discriminator
        # --------------------------        
        
        discr_pred_real = model.discriminator_forward(features.view(targets.size(0), 1, 28, 28))
        real_loss = F.binary_cross_entropy(discr_pred_real, valid)
        
        discr_pred_fake = model.discriminator_forward(generated_features.view(targets.size(0), 1, 28, 28).detach())
        fake_loss = F.binary_cross_entropy(discr_pred_fake, fake)
        
        discr_loss = 0.5*(real_loss + fake_loss)

        optim_discr.zero_grad()
        discr_loss.backward()
        optim_discr.step()        
        
        discr_costs.append(discr_loss.item())
        gener_costs.append(gener_loss.item())
        
        
        ### LOGGING
        if not batch_idx % 100:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Gen/Dis Loss: %.4f/%.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), gener_loss, discr_loss))

    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/100 | Batch 000/469 | Gen/Dis Loss: 0.6611/0.7405
# Epoch: 001/100 | Batch 100/469 | Gen/Dis Loss: 0.6405/0.7003
# Epoch: 001/100 | Batch 200/469 | Gen/Dis Loss: 0.6518/0.6971
# Epoch: 001/100 | Batch 300/469 | Gen/Dis Loss: 0.6617/0.6957
# Epoch: 001/100 | Batch 400/469 | Gen/Dis Loss: 0.6705/0.6947
# Time elapsed: 0.34 min
# Epoch: 002/100 | Batch 000/469 | Gen/Dis Loss: 0.6756/0.6944
# Epoch: 002/100 | Batch 100/469 | Gen/Dis Loss: 0.6818/0.6941
# Epoch: 002/100 | Batch 200/469 | Gen/Dis Loss: 0.6858/0.6938
# Epoch: 002/100 | Batch 300/469 | Gen/Dis Loss: 0.6890/0.6938
# Epoch: 002/100 | Batch 400/469 | Gen/Dis Loss: 0.6908/0.6936
# Time elapsed: 0.69 min
# Epoch: 003/100 | Batch 000/469 | Gen/Dis Loss: 0.6917/0.6936
# Epoch: 003/100 | Batch 100/469 | Gen/Dis Loss: 0.6925/0.6935
# Epoch: 003/100 | Batch 200/469 | Gen/Dis Loss: 0.6929/0.6935
# Epoch: 003/100 | Batch 300/469 | Gen/Dis Loss: 0.6930/0.6934
# Epoch: 003/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6934
# Time elapsed: 1.01 min
# Epoch: 004/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6934
# Epoch: 004/100 | Batch 100/469 | Gen/Dis Loss: 0.6933/0.6933
# Epoch: 004/100 | Batch 200/469 | Gen/Dis Loss: 0.6933/0.6933
# Epoch: 004/100 | Batch 300/469 | Gen/Dis Loss: 0.6933/0.6933
# Epoch: 004/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 1.35 min
# Epoch: 005/100 | Batch 000/469 | Gen/Dis Loss: 0.6933/0.6933
# Epoch: 005/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 005/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 005/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 005/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 1.69 min
# Epoch: 006/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 006/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 006/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 006/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 006/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 2.04 min
# Epoch: 007/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 007/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 007/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 007/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 007/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 2.38 min
# Epoch: 008/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 008/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 008/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 008/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 008/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 2.71 min
# Epoch: 009/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 009/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 009/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 009/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 009/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 3.07 min
# Epoch: 010/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 010/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 010/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 010/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 010/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 3.40 min
# Epoch: 011/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 011/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 011/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 011/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 011/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6932
# Time elapsed: 3.73 min
# Epoch: 012/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 012/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 012/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 012/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 012/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 4.08 min
# Epoch: 013/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 013/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 013/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 013/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 013/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 4.41 min
# Epoch: 014/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 014/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 014/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 014/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 014/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6932
# Time elapsed: 4.75 min
# Epoch: 015/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 015/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 015/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 015/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 015/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 5.09 min
# Epoch: 016/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 016/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 016/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 016/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 016/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 5.43 min
# Epoch: 017/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 017/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 017/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 017/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 017/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 5.77 min
# Epoch: 018/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 018/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 018/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 018/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6932
# Epoch: 018/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 6.11 min
# Epoch: 019/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 019/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6932
# Epoch: 019/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 019/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 019/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 6.44 min
# Epoch: 020/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 020/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 020/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 020/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 020/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 6.79 min
# Epoch: 021/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 021/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 021/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 021/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 021/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6932
# Time elapsed: 7.14 min
# Epoch: 022/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 022/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 022/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 022/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 022/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6932
# Time elapsed: 7.47 min
# Epoch: 023/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 023/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 023/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 023/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 023/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 7.81 min
# Epoch: 024/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 024/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 024/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 024/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 024/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 8.15 min
# Epoch: 025/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 025/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 025/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 025/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 025/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 8.45 min
# Epoch: 026/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 026/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 026/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 026/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 026/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 8.75 min
# Epoch: 027/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 027/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 027/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 027/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 027/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 9.05 min
# Epoch: 028/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 028/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 028/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 028/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 028/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 9.33 min
# Epoch: 029/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 029/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 029/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 029/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 029/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 9.57 min
# Epoch: 030/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 030/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 030/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 030/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 030/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 9.82 min
# Epoch: 031/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 031/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 031/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 031/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 031/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 10.09 min
# Epoch: 032/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 032/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 032/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 032/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 032/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 10.36 min
# Epoch: 033/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 033/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 033/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 033/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 033/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 10.63 min
# Epoch: 034/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 034/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 034/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 034/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 034/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 10.90 min
# Epoch: 035/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 035/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 035/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 035/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 035/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 11.17 min
# Epoch: 036/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 036/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 036/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 036/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 036/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 11.44 min
# Epoch: 037/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 037/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 037/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 037/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 037/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 11.72 min
# Epoch: 038/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 038/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 038/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 038/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 038/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 11.99 min
# Epoch: 039/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 039/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 039/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 039/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 039/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 12.26 min
# Epoch: 040/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 040/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 040/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 040/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 040/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 12.53 min
# Epoch: 041/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 041/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 041/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 041/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 041/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 12.80 min
# Epoch: 042/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 042/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 042/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 042/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 042/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 13.07 min
# Epoch: 043/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 043/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 043/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 043/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 043/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 13.34 min
# Epoch: 044/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 044/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 044/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 044/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 044/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 13.61 min
# Epoch: 045/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 045/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 045/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 045/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 045/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 13.88 min
# Epoch: 046/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 046/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 046/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 046/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 046/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 14.16 min
# Epoch: 047/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 047/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 047/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 047/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 047/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 14.43 min
# Epoch: 048/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 048/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 048/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 048/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 048/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 14.70 min
# Epoch: 049/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 049/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 049/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 049/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 049/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 14.95 min
# Epoch: 050/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 050/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 050/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 050/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 050/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 15.21 min
# Epoch: 051/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 051/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 051/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 051/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 051/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 15.48 min
# Epoch: 052/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 052/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 052/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 052/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 052/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 15.74 min
# Epoch: 053/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 053/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 053/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 053/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 053/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 16.01 min
# Epoch: 054/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 054/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 054/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 054/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 054/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 16.28 min
# Epoch: 055/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 055/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 055/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 055/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 055/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 16.55 min
# Epoch: 056/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 056/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 056/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 056/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 056/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 16.82 min
# Epoch: 057/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 057/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 057/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 057/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 057/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 17.09 min
# Epoch: 058/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 058/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 058/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 058/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 058/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 17.35 min
# Epoch: 059/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 059/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 059/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 059/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 059/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 17.62 min
# Epoch: 060/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 060/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 060/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 060/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 060/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 17.89 min
# Epoch: 061/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 061/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 061/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 061/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 061/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 18.14 min
# Epoch: 062/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 062/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 062/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 062/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 062/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 18.40 min
# Epoch: 063/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 063/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 063/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 063/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 063/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 18.66 min
# Epoch: 064/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 064/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 064/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 064/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 064/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 18.93 min
# Epoch: 065/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 065/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 065/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 065/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 065/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 19.20 min
# Epoch: 066/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 066/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 066/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 066/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 066/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 19.45 min
# Epoch: 067/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 067/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 067/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 067/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 067/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 19.69 min
# Epoch: 068/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 068/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 068/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 068/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 068/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 19.92 min
# Epoch: 069/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 069/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 069/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 069/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 069/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 20.17 min
# Epoch: 070/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 070/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 070/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 070/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 070/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 20.44 min
# Epoch: 071/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 071/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 071/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 071/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 071/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 20.72 min
# Epoch: 072/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 072/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 072/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 072/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 072/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 20.99 min
# Epoch: 073/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 073/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 073/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 073/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 073/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 21.26 min
# Epoch: 074/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 074/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 074/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 074/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 074/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 21.50 min
# Epoch: 075/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 075/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 075/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 075/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 075/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 21.76 min
# Epoch: 076/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 076/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 076/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 076/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 076/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 22.03 min
# Epoch: 077/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 077/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 077/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 077/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 077/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 22.28 min
# Epoch: 078/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 078/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 078/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 078/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 078/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 22.55 min
# Epoch: 079/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 079/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 079/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 079/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 079/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 22.82 min
# Epoch: 080/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 080/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 080/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 080/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 080/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 23.09 min
# Epoch: 081/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 081/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 081/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 081/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 081/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 23.36 min
# Epoch: 082/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 082/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 082/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 082/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 082/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 23.63 min
# Epoch: 083/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 083/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 083/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 083/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 083/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 23.89 min
# Epoch: 084/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 084/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 084/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 084/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 084/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 24.16 min
# Epoch: 085/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 085/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 085/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 085/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 085/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 24.42 min
# Epoch: 086/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 086/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 086/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 086/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 086/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 24.68 min
# Epoch: 087/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 087/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 087/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 087/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 087/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 24.95 min
# Epoch: 088/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 088/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 088/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 088/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 088/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 25.21 min
# Epoch: 089/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 089/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 089/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 089/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 089/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 25.47 min
# Epoch: 090/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 090/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 090/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 090/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 090/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 25.73 min
# Epoch: 091/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 091/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 091/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 091/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 091/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 25.98 min
# Epoch: 092/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 092/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 092/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 092/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 092/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 26.25 min
# Epoch: 093/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 093/100 | Batch 100/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 093/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 093/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 093/100 | Batch 400/469 | Gen/Dis Loss: 0.6932/0.6931
# Time elapsed: 26.49 min
# Epoch: 094/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 094/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 094/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 094/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 094/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 26.76 min
# Epoch: 095/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 095/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 095/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 095/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 095/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 27.03 min
# Epoch: 096/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 096/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 096/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 096/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 096/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 27.28 min
# Epoch: 097/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 097/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 097/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 097/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 097/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 27.54 min
# Epoch: 098/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 098/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 098/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 098/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 098/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 27.81 min
# Epoch: 099/100 | Batch 000/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 099/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 099/100 | Batch 200/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 099/100 | Batch 300/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 099/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 28.08 min
# Epoch: 100/100 | Batch 000/469 | Gen/Dis Loss: 0.6932/0.6931
# Epoch: 100/100 | Batch 100/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 100/100 | Batch 200/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 100/100 | Batch 300/469 | Gen/Dis Loss: 0.6931/0.6931
# Epoch: 100/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6931
# Time elapsed: 28.33 min
# Total Training Time: 28.33 min

# %%
### For Debugging

"""
for i in outputs:
    print(i.size())
"""
# Out:
# '\nfor i in outputs:\n    print(i.size())\n'

# %% [markdown]
# ## Evaluation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(gener_costs)), gener_costs, label='generator loss')
plt.plot(range(len(discr_costs)), discr_costs, label='discriminator loss')
plt.legend()
plt.show()

# %%
##########################
### VISUALIZATION
##########################


model.eval()
# Make new images
z = torch.zeros((5, LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
generated_features = model.generator_forward(z)
imgs = generated_features.view(-1, 28, 28)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 2.5))


for i, ax in enumerate(axes):
    axes[i].imshow(imgs[i].to(torch.device('cpu')).detach(), cmap='binary')
