# %% [markdown]
# STAT 453: Deep Learning (Spring 2020)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2020/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss20

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Sebastian Raschka
#
# CPython 3.7.3
# IPython 7.9.0
#
# torch 1.4.0

# %% [markdown]
# - Runs on CPU or GPU (if available)

# %% [markdown]
# # Generative Adversarial Networks (GAN)

# %% [markdown]
# Implementation of a standard GAN using a Multi-layer Perceptron for both the discriminator and generator.

# %% [markdown]
# ## Imports

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
from torch.utils.data import DataLoader


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Hyperparameters
random_seed = 123
generator_learning_rate = 0.001
discriminator_learning_rate = 0.001
num_epochs = 100
batch_size = 128
LATENT_DIM = 100
IMG_SHAPE = (1, 28, 28)
IMG_SIZE = 1
for x in IMG_SHAPE:
    IMG_SIZE *= x



##########################
### MNIST DATASET
##########################

# Note transforms.ToTensor() scales input images
# to 0-1 range
train_dataset = datasets.MNIST(root='data', 
                               train=True, 
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='data', 
                              train=False, 
                              transform=transforms.ToTensor())


train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=batch_size, 
                          shuffle=True)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=batch_size, 
                         shuffle=False)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# Processing...
# Done!
#
#
# Image batch dimensions: torch.Size([128, 1, 28, 28])
# Image label dimensions: torch.Size([128])

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################


class GAN(torch.nn.Module):

    def __init__(self):
        super(GAN, self).__init__()
        
        
        self.generator = nn.Sequential(
            nn.Linear(LATENT_DIM, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, IMG_SIZE),
            nn.Tanh()
        )
        
        self.discriminator = nn.Sequential(
            nn.Linear(IMG_SIZE, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

            
    def generator_forward(self, z):
        img = self.generator(z)
        return img
    
    def discriminator_forward(self, img):
        pred = model.discriminator(img)
        return pred.view(-1)

# %%
torch.manual_seed(random_seed)

model = GAN()
model = model.to(device)

optim_gener = torch.optim.Adam(model.generator.parameters(), lr=generator_learning_rate)
optim_discr = torch.optim.Adam(model.discriminator.parameters(), lr=discriminator_learning_rate)

# %% [markdown]
# ## Training

# %%
start_time = time.time()    

discr_costs = []
gener_costs = []
for epoch in range(num_epochs):
    model = model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):

        
        
        features = (features - 0.5)*2.
        features = features.view(-1, IMG_SIZE).to(device) 
        targets = targets.to(device)

        valid = torch.ones(targets.size(0)).float().to(device)
        fake = torch.zeros(targets.size(0)).float().to(device)
        

        ### FORWARD AND BACK PROP
        
        
        # --------------------------
        # Train Generator
        # --------------------------
        
        # Make new images
        z = torch.zeros((targets.size(0), LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
        generated_features = model.generator_forward(z)
        
        # Loss for fooling the discriminator
        discr_pred = model.discriminator_forward(generated_features)
        
        gener_loss = F.binary_cross_entropy(discr_pred, valid)
        
        optim_gener.zero_grad()
        gener_loss.backward()
        optim_gener.step()
        
        # --------------------------
        # Train Discriminator
        # --------------------------        
        
        discr_pred_real = model.discriminator_forward(features.view(-1, IMG_SIZE))
        real_loss = F.binary_cross_entropy(discr_pred_real, valid)
        
        discr_pred_fake = model.discriminator_forward(generated_features.detach())
        fake_loss = F.binary_cross_entropy(discr_pred_fake, fake)
        
        discr_loss = 0.5*(real_loss + fake_loss)

        optim_discr.zero_grad()
        discr_loss.backward()
        optim_discr.step()        
        
        discr_costs.append(discr_loss.item())
        gener_costs.append(gener_loss.item())
        
        
        ### LOGGING
        if not batch_idx % 100:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Gen/Dis Loss: %.4f/%.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), gener_loss, discr_loss))

    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/100 | Batch 000/469 | Gen/Dis Loss: 0.6840/0.7187
# Epoch: 001/100 | Batch 100/469 | Gen/Dis Loss: 4.5633/0.0415
# Epoch: 001/100 | Batch 200/469 | Gen/Dis Loss: 1.8593/0.0951
# Epoch: 001/100 | Batch 300/469 | Gen/Dis Loss: 1.4109/0.1606
# Epoch: 001/100 | Batch 400/469 | Gen/Dis Loss: 2.3064/0.0832
# Time elapsed: 0.15 min
# Epoch: 002/100 | Batch 000/469 | Gen/Dis Loss: 2.1248/0.1343
# Epoch: 002/100 | Batch 100/469 | Gen/Dis Loss: 2.0219/0.1749
# Epoch: 002/100 | Batch 200/469 | Gen/Dis Loss: 1.5997/0.3642
# Epoch: 002/100 | Batch 300/469 | Gen/Dis Loss: 1.1501/0.4512
# Epoch: 002/100 | Batch 400/469 | Gen/Dis Loss: 0.9979/0.4534
# Time elapsed: 0.29 min
# Epoch: 003/100 | Batch 000/469 | Gen/Dis Loss: 1.2436/0.3536
# Epoch: 003/100 | Batch 100/469 | Gen/Dis Loss: 0.6480/0.5489
# Epoch: 003/100 | Batch 200/469 | Gen/Dis Loss: 0.7793/0.5393
# Epoch: 003/100 | Batch 300/469 | Gen/Dis Loss: 0.7613/0.5952
# Epoch: 003/100 | Batch 400/469 | Gen/Dis Loss: 0.6549/0.6205
# Time elapsed: 0.43 min
# Epoch: 004/100 | Batch 000/469 | Gen/Dis Loss: 1.2507/0.5088
# Epoch: 004/100 | Batch 100/469 | Gen/Dis Loss: 1.3985/0.5694
# Epoch: 004/100 | Batch 200/469 | Gen/Dis Loss: 1.1761/0.4893
# Epoch: 004/100 | Batch 300/469 | Gen/Dis Loss: 0.6691/0.5599
# Epoch: 004/100 | Batch 400/469 | Gen/Dis Loss: 1.2617/0.5071
# Time elapsed: 0.57 min
# Epoch: 005/100 | Batch 000/469 | Gen/Dis Loss: 0.8874/0.5308
# Epoch: 005/100 | Batch 100/469 | Gen/Dis Loss: 1.4255/0.5431
# Epoch: 005/100 | Batch 200/469 | Gen/Dis Loss: 1.0041/0.6178
# Epoch: 005/100 | Batch 300/469 | Gen/Dis Loss: 0.8777/0.5441
# Epoch: 005/100 | Batch 400/469 | Gen/Dis Loss: 1.0321/0.5663
# Time elapsed: 0.71 min
# Epoch: 006/100 | Batch 000/469 | Gen/Dis Loss: 0.8611/0.6272
# Epoch: 006/100 | Batch 100/469 | Gen/Dis Loss: 0.8416/0.5973
# Epoch: 006/100 | Batch 200/469 | Gen/Dis Loss: 0.9676/0.4989
# Epoch: 006/100 | Batch 300/469 | Gen/Dis Loss: 0.7488/0.6022
# Epoch: 006/100 | Batch 400/469 | Gen/Dis Loss: 0.8261/0.5695
# Time elapsed: 0.85 min
# Epoch: 007/100 | Batch 000/469 | Gen/Dis Loss: 2.0746/0.5618
# Epoch: 007/100 | Batch 100/469 | Gen/Dis Loss: 1.9684/0.4381
# Epoch: 007/100 | Batch 200/469 | Gen/Dis Loss: 0.9837/0.4742
# Epoch: 007/100 | Batch 300/469 | Gen/Dis Loss: 1.5332/0.5464
# Epoch: 007/100 | Batch 400/469 | Gen/Dis Loss: 1.1689/0.4815
# Time elapsed: 0.99 min
# Epoch: 008/100 | Batch 000/469 | Gen/Dis Loss: 1.4390/0.4819
# Epoch: 008/100 | Batch 100/469 | Gen/Dis Loss: 0.9377/0.4920
# Epoch: 008/100 | Batch 200/469 | Gen/Dis Loss: 0.9973/0.4829
# Epoch: 008/100 | Batch 300/469 | Gen/Dis Loss: 1.0835/0.5289
# Epoch: 008/100 | Batch 400/469 | Gen/Dis Loss: 1.2866/0.4791
# Time elapsed: 1.13 min
# Epoch: 009/100 | Batch 000/469 | Gen/Dis Loss: 1.1437/0.4902
# Epoch: 009/100 | Batch 100/469 | Gen/Dis Loss: 1.1265/0.4442
# Epoch: 009/100 | Batch 200/469 | Gen/Dis Loss: 1.2893/0.4795
# Epoch: 009/100 | Batch 300/469 | Gen/Dis Loss: 1.2383/0.5032
# Epoch: 009/100 | Batch 400/469 | Gen/Dis Loss: 1.2463/0.4873
# Time elapsed: 1.27 min
# Epoch: 010/100 | Batch 000/469 | Gen/Dis Loss: 1.3625/0.4758
# Epoch: 010/100 | Batch 100/469 | Gen/Dis Loss: 1.7212/0.4259
# Epoch: 010/100 | Batch 200/469 | Gen/Dis Loss: 1.2340/0.4400
# Epoch: 010/100 | Batch 300/469 | Gen/Dis Loss: 1.2550/0.4264
# Epoch: 010/100 | Batch 400/469 | Gen/Dis Loss: 1.0047/0.4945
# Time elapsed: 1.41 min
# Epoch: 011/100 | Batch 000/469 | Gen/Dis Loss: 1.6716/0.5128
# Epoch: 011/100 | Batch 100/469 | Gen/Dis Loss: 1.2985/0.4845
# Epoch: 011/100 | Batch 200/469 | Gen/Dis Loss: 1.1158/0.5547
# Epoch: 011/100 | Batch 300/469 | Gen/Dis Loss: 1.0207/0.5415
# Epoch: 011/100 | Batch 400/469 | Gen/Dis Loss: 1.4210/0.4773
# Time elapsed: 1.56 min
# Epoch: 012/100 | Batch 000/469 | Gen/Dis Loss: 1.7628/0.4337
# Epoch: 012/100 | Batch 100/469 | Gen/Dis Loss: 1.1690/0.5519
# Epoch: 012/100 | Batch 200/469 | Gen/Dis Loss: 1.9387/0.4902
# Epoch: 012/100 | Batch 300/469 | Gen/Dis Loss: 1.0749/0.4431
# Epoch: 012/100 | Batch 400/469 | Gen/Dis Loss: 1.7975/0.4520
# Time elapsed: 1.73 min
# Epoch: 013/100 | Batch 000/469 | Gen/Dis Loss: 1.2410/0.5515
# Epoch: 013/100 | Batch 100/469 | Gen/Dis Loss: 1.0668/0.5449
# Epoch: 013/100 | Batch 200/469 | Gen/Dis Loss: 1.1793/0.5392
# Epoch: 013/100 | Batch 300/469 | Gen/Dis Loss: 1.1094/0.5435
# Epoch: 013/100 | Batch 400/469 | Gen/Dis Loss: 1.3073/0.5185
# Time elapsed: 1.89 min
# Epoch: 014/100 | Batch 000/469 | Gen/Dis Loss: 1.0348/0.5156
# Epoch: 014/100 | Batch 100/469 | Gen/Dis Loss: 1.4403/0.4663
# Epoch: 014/100 | Batch 200/469 | Gen/Dis Loss: 1.3284/0.4886
# Epoch: 014/100 | Batch 300/469 | Gen/Dis Loss: 1.0302/0.5052
# Epoch: 014/100 | Batch 400/469 | Gen/Dis Loss: 1.2798/0.4746
# Time elapsed: 2.06 min
# Epoch: 015/100 | Batch 000/469 | Gen/Dis Loss: 1.1742/0.4652
# Epoch: 015/100 | Batch 100/469 | Gen/Dis Loss: 1.5275/0.5150
# Epoch: 015/100 | Batch 200/469 | Gen/Dis Loss: 1.4828/0.4700
# Epoch: 015/100 | Batch 300/469 | Gen/Dis Loss: 1.2150/0.5308
# Epoch: 015/100 | Batch 400/469 | Gen/Dis Loss: 1.0153/0.5811
# Time elapsed: 2.22 min
# Epoch: 016/100 | Batch 000/469 | Gen/Dis Loss: 1.1513/0.4795
# Epoch: 016/100 | Batch 100/469 | Gen/Dis Loss: 1.2664/0.4806
# Epoch: 016/100 | Batch 200/469 | Gen/Dis Loss: 1.1853/0.4876
# Epoch: 016/100 | Batch 300/469 | Gen/Dis Loss: 0.9563/0.6715
# Epoch: 016/100 | Batch 400/469 | Gen/Dis Loss: 1.4823/0.3883
# Time elapsed: 2.37 min
# Epoch: 017/100 | Batch 000/469 | Gen/Dis Loss: 0.9500/0.5626
# Epoch: 017/100 | Batch 100/469 | Gen/Dis Loss: 1.0556/0.4862
# Epoch: 017/100 | Batch 200/469 | Gen/Dis Loss: 1.3563/0.5556
# Epoch: 017/100 | Batch 300/469 | Gen/Dis Loss: 1.1905/0.5759
# Epoch: 017/100 | Batch 400/469 | Gen/Dis Loss: 1.4459/0.5389
# Time elapsed: 2.56 min
# Epoch: 018/100 | Batch 000/469 | Gen/Dis Loss: 1.2070/0.5325
# Epoch: 018/100 | Batch 100/469 | Gen/Dis Loss: 0.9276/0.5574
# Epoch: 018/100 | Batch 200/469 | Gen/Dis Loss: 1.2075/0.4992
# Epoch: 018/100 | Batch 300/469 | Gen/Dis Loss: 1.2366/0.5774
# Epoch: 018/100 | Batch 400/469 | Gen/Dis Loss: 1.7655/0.5661
# Time elapsed: 2.75 min
# Epoch: 019/100 | Batch 000/469 | Gen/Dis Loss: 1.1416/0.5293
# Epoch: 019/100 | Batch 100/469 | Gen/Dis Loss: 0.9768/0.6032
# Epoch: 019/100 | Batch 200/469 | Gen/Dis Loss: 0.9739/0.5431
# Epoch: 019/100 | Batch 300/469 | Gen/Dis Loss: 1.0701/0.4716
# Epoch: 019/100 | Batch 400/469 | Gen/Dis Loss: 1.0509/0.5092
# Time elapsed: 2.94 min
# Epoch: 020/100 | Batch 000/469 | Gen/Dis Loss: 0.9757/0.5607
# Epoch: 020/100 | Batch 100/469 | Gen/Dis Loss: 1.1461/0.5333
# Epoch: 020/100 | Batch 200/469 | Gen/Dis Loss: 1.1359/0.5050
# Epoch: 020/100 | Batch 300/469 | Gen/Dis Loss: 0.9834/0.5695
# Epoch: 020/100 | Batch 400/469 | Gen/Dis Loss: 1.1001/0.5711
# Time elapsed: 3.14 min
# Epoch: 021/100 | Batch 000/469 | Gen/Dis Loss: 0.9457/0.5531
# Epoch: 021/100 | Batch 100/469 | Gen/Dis Loss: 1.3923/0.5247
# Epoch: 021/100 | Batch 200/469 | Gen/Dis Loss: 0.8958/0.5458
# Epoch: 021/100 | Batch 300/469 | Gen/Dis Loss: 1.2522/0.5316
# Epoch: 021/100 | Batch 400/469 | Gen/Dis Loss: 0.9660/0.6538
# Time elapsed: 3.33 min
# Epoch: 022/100 | Batch 000/469 | Gen/Dis Loss: 1.0923/0.5081
# Epoch: 022/100 | Batch 100/469 | Gen/Dis Loss: 1.3321/0.5123
# Epoch: 022/100 | Batch 200/469 | Gen/Dis Loss: 1.1332/0.5083
# Epoch: 022/100 | Batch 300/469 | Gen/Dis Loss: 1.0153/0.5353
# Epoch: 022/100 | Batch 400/469 | Gen/Dis Loss: 1.0980/0.5761
# Time elapsed: 3.51 min
# Epoch: 023/100 | Batch 000/469 | Gen/Dis Loss: 1.1412/0.4720
# Epoch: 023/100 | Batch 100/469 | Gen/Dis Loss: 1.3064/0.5555
# Epoch: 023/100 | Batch 200/469 | Gen/Dis Loss: 0.9426/0.5310
# Epoch: 023/100 | Batch 300/469 | Gen/Dis Loss: 1.4457/0.4817
# Epoch: 023/100 | Batch 400/469 | Gen/Dis Loss: 0.9990/0.5143
# Time elapsed: 3.71 min
# Epoch: 024/100 | Batch 000/469 | Gen/Dis Loss: 1.6132/0.5640
# Epoch: 024/100 | Batch 100/469 | Gen/Dis Loss: 1.3420/0.5712
# Epoch: 024/100 | Batch 200/469 | Gen/Dis Loss: 1.0739/0.6113
# Epoch: 024/100 | Batch 300/469 | Gen/Dis Loss: 1.2552/0.6045
# Epoch: 024/100 | Batch 400/469 | Gen/Dis Loss: 1.3891/0.5721
# Time elapsed: 3.90 min
# Epoch: 025/100 | Batch 000/469 | Gen/Dis Loss: 1.0055/0.6159
# Epoch: 025/100 | Batch 100/469 | Gen/Dis Loss: 1.3490/0.5200
# Epoch: 025/100 | Batch 200/469 | Gen/Dis Loss: 1.0851/0.5541
# Epoch: 025/100 | Batch 300/469 | Gen/Dis Loss: 0.9722/0.6214
# Epoch: 025/100 | Batch 400/469 | Gen/Dis Loss: 1.1328/0.5860
# Time elapsed: 4.09 min
# Epoch: 026/100 | Batch 000/469 | Gen/Dis Loss: 1.0734/0.5704
# Epoch: 026/100 | Batch 100/469 | Gen/Dis Loss: 1.1116/0.5607
# Epoch: 026/100 | Batch 200/469 | Gen/Dis Loss: 0.9087/0.5617
# Epoch: 026/100 | Batch 300/469 | Gen/Dis Loss: 0.9659/0.5894
# Epoch: 026/100 | Batch 400/469 | Gen/Dis Loss: 1.0313/0.6348
# Time elapsed: 4.28 min
# Epoch: 027/100 | Batch 000/469 | Gen/Dis Loss: 1.0365/0.5432
# Epoch: 027/100 | Batch 100/469 | Gen/Dis Loss: 0.8759/0.5339
# Epoch: 027/100 | Batch 200/469 | Gen/Dis Loss: 1.4294/0.5997
# Epoch: 027/100 | Batch 300/469 | Gen/Dis Loss: 1.0292/0.5722
# Epoch: 027/100 | Batch 400/469 | Gen/Dis Loss: 0.8141/0.6168
# Time elapsed: 4.47 min
# Epoch: 028/100 | Batch 000/469 | Gen/Dis Loss: 0.8155/0.6201
# Epoch: 028/100 | Batch 100/469 | Gen/Dis Loss: 1.1135/0.5701
# Epoch: 028/100 | Batch 200/469 | Gen/Dis Loss: 0.8652/0.6011
# Epoch: 028/100 | Batch 300/469 | Gen/Dis Loss: 1.1095/0.5406
# Epoch: 028/100 | Batch 400/469 | Gen/Dis Loss: 0.9503/0.5663
# Time elapsed: 4.66 min
# Epoch: 029/100 | Batch 000/469 | Gen/Dis Loss: 0.9892/0.5300
# Epoch: 029/100 | Batch 100/469 | Gen/Dis Loss: 0.9346/0.5969
# Epoch: 029/100 | Batch 200/469 | Gen/Dis Loss: 1.0156/0.5889
# Epoch: 029/100 | Batch 300/469 | Gen/Dis Loss: 1.1976/0.6109
# Epoch: 029/100 | Batch 400/469 | Gen/Dis Loss: 1.5120/0.5739
# Time elapsed: 4.86 min
# Epoch: 030/100 | Batch 000/469 | Gen/Dis Loss: 1.1149/0.5747
# Epoch: 030/100 | Batch 100/469 | Gen/Dis Loss: 1.0073/0.5608
# Epoch: 030/100 | Batch 200/469 | Gen/Dis Loss: 0.8989/0.5912
# Epoch: 030/100 | Batch 300/469 | Gen/Dis Loss: 1.1094/0.5661
# Epoch: 030/100 | Batch 400/469 | Gen/Dis Loss: 1.0330/0.6173
# Time elapsed: 5.05 min
# Epoch: 031/100 | Batch 000/469 | Gen/Dis Loss: 0.9963/0.5787
# Epoch: 031/100 | Batch 100/469 | Gen/Dis Loss: 0.9608/0.5889
# Epoch: 031/100 | Batch 200/469 | Gen/Dis Loss: 1.0776/0.5743
# Epoch: 031/100 | Batch 300/469 | Gen/Dis Loss: 1.0571/0.5789
# Epoch: 031/100 | Batch 400/469 | Gen/Dis Loss: 1.0013/0.6492
# Time elapsed: 5.24 min
# Epoch: 032/100 | Batch 000/469 | Gen/Dis Loss: 1.0117/0.6029
# Epoch: 032/100 | Batch 100/469 | Gen/Dis Loss: 1.0593/0.5867
# Epoch: 032/100 | Batch 200/469 | Gen/Dis Loss: 1.3300/0.5781
# Epoch: 032/100 | Batch 300/469 | Gen/Dis Loss: 0.8843/0.5885
# Epoch: 032/100 | Batch 400/469 | Gen/Dis Loss: 1.0461/0.5804
# Time elapsed: 5.43 min
# Epoch: 033/100 | Batch 000/469 | Gen/Dis Loss: 0.8573/0.6253
# Epoch: 033/100 | Batch 100/469 | Gen/Dis Loss: 1.3011/0.5515
# Epoch: 033/100 | Batch 200/469 | Gen/Dis Loss: 0.8749/0.6456
# Epoch: 033/100 | Batch 300/469 | Gen/Dis Loss: 1.0175/0.5614
# Epoch: 033/100 | Batch 400/469 | Gen/Dis Loss: 0.8803/0.5802
# Time elapsed: 5.62 min
# Epoch: 034/100 | Batch 000/469 | Gen/Dis Loss: 0.8105/0.6235
# Epoch: 034/100 | Batch 100/469 | Gen/Dis Loss: 0.9629/0.6273
# Epoch: 034/100 | Batch 200/469 | Gen/Dis Loss: 1.1421/0.5750
# Epoch: 034/100 | Batch 300/469 | Gen/Dis Loss: 0.9778/0.6045
# Epoch: 034/100 | Batch 400/469 | Gen/Dis Loss: 0.8442/0.6399
# Time elapsed: 5.80 min
# Epoch: 035/100 | Batch 000/469 | Gen/Dis Loss: 0.8060/0.6130
# Epoch: 035/100 | Batch 100/469 | Gen/Dis Loss: 0.8575/0.5983
# Epoch: 035/100 | Batch 200/469 | Gen/Dis Loss: 1.1089/0.5691
# Epoch: 035/100 | Batch 300/469 | Gen/Dis Loss: 0.9712/0.6117
# Epoch: 035/100 | Batch 400/469 | Gen/Dis Loss: 0.7721/0.6709
# Time elapsed: 6.00 min
# Epoch: 036/100 | Batch 000/469 | Gen/Dis Loss: 1.1330/0.5470
# Epoch: 036/100 | Batch 100/469 | Gen/Dis Loss: 0.8933/0.6053
# Epoch: 036/100 | Batch 200/469 | Gen/Dis Loss: 1.0225/0.5647
# Epoch: 036/100 | Batch 300/469 | Gen/Dis Loss: 1.0984/0.5747
# Epoch: 036/100 | Batch 400/469 | Gen/Dis Loss: 0.9456/0.5827
# Time elapsed: 6.19 min
# Epoch: 037/100 | Batch 000/469 | Gen/Dis Loss: 1.0882/0.6107
# Epoch: 037/100 | Batch 100/469 | Gen/Dis Loss: 1.0754/0.4945
# Epoch: 037/100 | Batch 200/469 | Gen/Dis Loss: 1.1307/0.5682
# Epoch: 037/100 | Batch 300/469 | Gen/Dis Loss: 0.8820/0.6465
# Epoch: 037/100 | Batch 400/469 | Gen/Dis Loss: 0.9315/0.6231
# Time elapsed: 6.38 min
# Epoch: 038/100 | Batch 000/469 | Gen/Dis Loss: 1.0219/0.5841
# Epoch: 038/100 | Batch 100/469 | Gen/Dis Loss: 0.9937/0.6073
# Epoch: 038/100 | Batch 200/469 | Gen/Dis Loss: 1.0014/0.6057
# Epoch: 038/100 | Batch 300/469 | Gen/Dis Loss: 0.8445/0.6481
# Epoch: 038/100 | Batch 400/469 | Gen/Dis Loss: 1.1158/0.5396
# Time elapsed: 6.57 min
# Epoch: 039/100 | Batch 000/469 | Gen/Dis Loss: 0.9197/0.5576
# Epoch: 039/100 | Batch 100/469 | Gen/Dis Loss: 0.9481/0.5674
# Epoch: 039/100 | Batch 200/469 | Gen/Dis Loss: 0.8736/0.6261
# Epoch: 039/100 | Batch 300/469 | Gen/Dis Loss: 1.0000/0.6386
# Epoch: 039/100 | Batch 400/469 | Gen/Dis Loss: 0.9492/0.6175
# Time elapsed: 6.76 min
# Epoch: 040/100 | Batch 000/469 | Gen/Dis Loss: 0.9563/0.5876
# Epoch: 040/100 | Batch 100/469 | Gen/Dis Loss: 0.8335/0.6162
# Epoch: 040/100 | Batch 200/469 | Gen/Dis Loss: 0.9257/0.5757
# Epoch: 040/100 | Batch 300/469 | Gen/Dis Loss: 1.0089/0.5997
# Epoch: 040/100 | Batch 400/469 | Gen/Dis Loss: 1.0605/0.5692
# Time elapsed: 6.95 min
# Epoch: 041/100 | Batch 000/469 | Gen/Dis Loss: 0.9809/0.5932
# Epoch: 041/100 | Batch 100/469 | Gen/Dis Loss: 0.8645/0.6145
# Epoch: 041/100 | Batch 200/469 | Gen/Dis Loss: 1.0900/0.6345
# Epoch: 041/100 | Batch 300/469 | Gen/Dis Loss: 1.0021/0.6183
# Epoch: 041/100 | Batch 400/469 | Gen/Dis Loss: 0.9441/0.6320
# Time elapsed: 7.14 min
# Epoch: 042/100 | Batch 000/469 | Gen/Dis Loss: 0.9371/0.6291
# Epoch: 042/100 | Batch 100/469 | Gen/Dis Loss: 1.0256/0.6212
# Epoch: 042/100 | Batch 200/469 | Gen/Dis Loss: 0.9513/0.6080
# Epoch: 042/100 | Batch 300/469 | Gen/Dis Loss: 0.8378/0.6297
# Epoch: 042/100 | Batch 400/469 | Gen/Dis Loss: 0.7959/0.5696
# Time elapsed: 7.34 min
# Epoch: 043/100 | Batch 000/469 | Gen/Dis Loss: 0.8258/0.6527
# Epoch: 043/100 | Batch 100/469 | Gen/Dis Loss: 1.4202/0.6108
# Epoch: 043/100 | Batch 200/469 | Gen/Dis Loss: 0.8493/0.6337
# Epoch: 043/100 | Batch 300/469 | Gen/Dis Loss: 0.8943/0.6277
# Epoch: 043/100 | Batch 400/469 | Gen/Dis Loss: 0.9265/0.5841
# Time elapsed: 7.52 min
# Epoch: 044/100 | Batch 000/469 | Gen/Dis Loss: 1.0870/0.6292
# Epoch: 044/100 | Batch 100/469 | Gen/Dis Loss: 0.7937/0.6369
# Epoch: 044/100 | Batch 200/469 | Gen/Dis Loss: 0.7962/0.5982
# Epoch: 044/100 | Batch 300/469 | Gen/Dis Loss: 1.1642/0.5868
# Epoch: 044/100 | Batch 400/469 | Gen/Dis Loss: 0.8535/0.6179
# Time elapsed: 7.71 min
# Epoch: 045/100 | Batch 000/469 | Gen/Dis Loss: 0.8457/0.6367
# Epoch: 045/100 | Batch 100/469 | Gen/Dis Loss: 1.0067/0.6233
# Epoch: 045/100 | Batch 200/469 | Gen/Dis Loss: 0.9123/0.6243
# Epoch: 045/100 | Batch 300/469 | Gen/Dis Loss: 0.8565/0.5831
# Epoch: 045/100 | Batch 400/469 | Gen/Dis Loss: 0.8331/0.6664
# Time elapsed: 7.90 min
# Epoch: 046/100 | Batch 000/469 | Gen/Dis Loss: 1.0350/0.6399
# Epoch: 046/100 | Batch 100/469 | Gen/Dis Loss: 0.8127/0.5839
# Epoch: 046/100 | Batch 200/469 | Gen/Dis Loss: 0.9261/0.6430
# Epoch: 046/100 | Batch 300/469 | Gen/Dis Loss: 0.8334/0.6015
# Epoch: 046/100 | Batch 400/469 | Gen/Dis Loss: 0.8227/0.6625
# Time elapsed: 8.10 min
# Epoch: 047/100 | Batch 000/469 | Gen/Dis Loss: 0.9415/0.6094
# Epoch: 047/100 | Batch 100/469 | Gen/Dis Loss: 1.0479/0.6501
# Epoch: 047/100 | Batch 200/469 | Gen/Dis Loss: 0.8133/0.6267
# Epoch: 047/100 | Batch 300/469 | Gen/Dis Loss: 0.8975/0.6175
# Epoch: 047/100 | Batch 400/469 | Gen/Dis Loss: 0.8582/0.6644
# Time elapsed: 8.29 min
# Epoch: 048/100 | Batch 000/469 | Gen/Dis Loss: 0.8719/0.6248
# Epoch: 048/100 | Batch 100/469 | Gen/Dis Loss: 0.8170/0.6438
# Epoch: 048/100 | Batch 200/469 | Gen/Dis Loss: 0.9174/0.6176
# Epoch: 048/100 | Batch 300/469 | Gen/Dis Loss: 0.9238/0.6299
# Epoch: 048/100 | Batch 400/469 | Gen/Dis Loss: 0.8996/0.6177
# Time elapsed: 8.47 min
# Epoch: 049/100 | Batch 000/469 | Gen/Dis Loss: 0.8053/0.6462
# Epoch: 049/100 | Batch 100/469 | Gen/Dis Loss: 0.9641/0.5792
# Epoch: 049/100 | Batch 200/469 | Gen/Dis Loss: 0.8195/0.6271
# Epoch: 049/100 | Batch 300/469 | Gen/Dis Loss: 0.8868/0.6704
# Epoch: 049/100 | Batch 400/469 | Gen/Dis Loss: 1.2079/0.6350
# Time elapsed: 8.66 min
# Epoch: 050/100 | Batch 000/469 | Gen/Dis Loss: 0.8226/0.6451
# Epoch: 050/100 | Batch 100/469 | Gen/Dis Loss: 0.9630/0.6448
# Epoch: 050/100 | Batch 200/469 | Gen/Dis Loss: 0.8714/0.5711
# Epoch: 050/100 | Batch 300/469 | Gen/Dis Loss: 0.9619/0.6386
# Epoch: 050/100 | Batch 400/469 | Gen/Dis Loss: 0.9310/0.6627
# Time elapsed: 8.85 min
# Epoch: 051/100 | Batch 000/469 | Gen/Dis Loss: 0.9318/0.6211
# Epoch: 051/100 | Batch 100/469 | Gen/Dis Loss: 0.7801/0.6575
# Epoch: 051/100 | Batch 200/469 | Gen/Dis Loss: 0.9163/0.6132
# Epoch: 051/100 | Batch 300/469 | Gen/Dis Loss: 0.7743/0.6459
# Epoch: 051/100 | Batch 400/469 | Gen/Dis Loss: 0.6980/0.6693
# Time elapsed: 9.04 min
# Epoch: 052/100 | Batch 000/469 | Gen/Dis Loss: 0.7896/0.6575
# Epoch: 052/100 | Batch 100/469 | Gen/Dis Loss: 0.9494/0.6461
# Epoch: 052/100 | Batch 200/469 | Gen/Dis Loss: 0.8512/0.6191
# Epoch: 052/100 | Batch 300/469 | Gen/Dis Loss: 0.8029/0.6002
# Epoch: 052/100 | Batch 400/469 | Gen/Dis Loss: 0.7892/0.6762
# Time elapsed: 9.23 min
# Epoch: 053/100 | Batch 000/469 | Gen/Dis Loss: 0.9735/0.6455
# Epoch: 053/100 | Batch 100/469 | Gen/Dis Loss: 0.8035/0.6514
# Epoch: 053/100 | Batch 200/469 | Gen/Dis Loss: 0.9348/0.6207
# Epoch: 053/100 | Batch 300/469 | Gen/Dis Loss: 0.9448/0.6203
# Epoch: 053/100 | Batch 400/469 | Gen/Dis Loss: 0.8149/0.6543
# Time elapsed: 9.42 min
# Epoch: 054/100 | Batch 000/469 | Gen/Dis Loss: 0.8032/0.6592
# Epoch: 054/100 | Batch 100/469 | Gen/Dis Loss: 0.8478/0.6007
# Epoch: 054/100 | Batch 200/469 | Gen/Dis Loss: 1.0281/0.6482
# Epoch: 054/100 | Batch 300/469 | Gen/Dis Loss: 0.7810/0.6355
# Epoch: 054/100 | Batch 400/469 | Gen/Dis Loss: 1.0329/0.6052
# Time elapsed: 9.61 min
# Epoch: 055/100 | Batch 000/469 | Gen/Dis Loss: 0.9654/0.6148
# Epoch: 055/100 | Batch 100/469 | Gen/Dis Loss: 1.0046/0.6635
# Epoch: 055/100 | Batch 200/469 | Gen/Dis Loss: 0.8387/0.6496
# Epoch: 055/100 | Batch 300/469 | Gen/Dis Loss: 0.8648/0.6473
# Epoch: 055/100 | Batch 400/469 | Gen/Dis Loss: 0.8095/0.6422
# Time elapsed: 9.80 min
# Epoch: 056/100 | Batch 000/469 | Gen/Dis Loss: 0.8394/0.6264
# Epoch: 056/100 | Batch 100/469 | Gen/Dis Loss: 0.8839/0.6299
# Epoch: 056/100 | Batch 200/469 | Gen/Dis Loss: 0.7984/0.6697
# Epoch: 056/100 | Batch 300/469 | Gen/Dis Loss: 0.8114/0.6260
# Epoch: 056/100 | Batch 400/469 | Gen/Dis Loss: 0.8979/0.6449
# Time elapsed: 9.99 min
# Epoch: 057/100 | Batch 000/469 | Gen/Dis Loss: 0.8082/0.6010
# Epoch: 057/100 | Batch 100/469 | Gen/Dis Loss: 0.8563/0.6692
# Epoch: 057/100 | Batch 200/469 | Gen/Dis Loss: 0.8193/0.6226
# Epoch: 057/100 | Batch 300/469 | Gen/Dis Loss: 0.9141/0.6407
# Epoch: 057/100 | Batch 400/469 | Gen/Dis Loss: 0.8797/0.6443
# Time elapsed: 10.18 min
# Epoch: 058/100 | Batch 000/469 | Gen/Dis Loss: 0.9076/0.6362
# Epoch: 058/100 | Batch 100/469 | Gen/Dis Loss: 1.2590/0.5908
# Epoch: 058/100 | Batch 200/469 | Gen/Dis Loss: 0.7823/0.6266
# Epoch: 058/100 | Batch 300/469 | Gen/Dis Loss: 0.8937/0.6458
# Epoch: 058/100 | Batch 400/469 | Gen/Dis Loss: 0.7505/0.6457
# Time elapsed: 10.36 min
# Epoch: 059/100 | Batch 000/469 | Gen/Dis Loss: 0.7835/0.6240
# Epoch: 059/100 | Batch 100/469 | Gen/Dis Loss: 0.8286/0.6652
# Epoch: 059/100 | Batch 200/469 | Gen/Dis Loss: 0.8256/0.6289
# Epoch: 059/100 | Batch 300/469 | Gen/Dis Loss: 0.8762/0.6123
# Epoch: 059/100 | Batch 400/469 | Gen/Dis Loss: 0.8764/0.6349
# Time elapsed: 10.55 min
# Epoch: 060/100 | Batch 000/469 | Gen/Dis Loss: 0.9035/0.6491
# Epoch: 060/100 | Batch 100/469 | Gen/Dis Loss: 1.0670/0.6369
# Epoch: 060/100 | Batch 200/469 | Gen/Dis Loss: 0.9150/0.6443
# Epoch: 060/100 | Batch 300/469 | Gen/Dis Loss: 1.0966/0.6472
# Epoch: 060/100 | Batch 400/469 | Gen/Dis Loss: 0.8659/0.6517
# Time elapsed: 10.74 min
# Epoch: 061/100 | Batch 000/469 | Gen/Dis Loss: 0.8336/0.6700
# Epoch: 061/100 | Batch 100/469 | Gen/Dis Loss: 0.8300/0.6292
# Epoch: 061/100 | Batch 200/469 | Gen/Dis Loss: 1.2126/0.5765
# Epoch: 061/100 | Batch 300/469 | Gen/Dis Loss: 0.8368/0.6783
# Epoch: 061/100 | Batch 400/469 | Gen/Dis Loss: 0.8466/0.6628
# Time elapsed: 10.93 min
# Epoch: 062/100 | Batch 000/469 | Gen/Dis Loss: 0.8632/0.6111
# Epoch: 062/100 | Batch 100/469 | Gen/Dis Loss: 0.8738/0.6503
# Epoch: 062/100 | Batch 200/469 | Gen/Dis Loss: 1.1108/0.6799
# Epoch: 062/100 | Batch 300/469 | Gen/Dis Loss: 0.7670/0.6258
# Epoch: 062/100 | Batch 400/469 | Gen/Dis Loss: 1.1119/0.6420
# Time elapsed: 11.12 min
# Epoch: 063/100 | Batch 000/469 | Gen/Dis Loss: 0.8431/0.6224
# Epoch: 063/100 | Batch 100/469 | Gen/Dis Loss: 0.8165/0.6684
# Epoch: 063/100 | Batch 200/469 | Gen/Dis Loss: 0.7000/0.6224
# Epoch: 063/100 | Batch 300/469 | Gen/Dis Loss: 0.8744/0.6347
# Epoch: 063/100 | Batch 400/469 | Gen/Dis Loss: 0.8501/0.6370
# Time elapsed: 11.31 min
# Epoch: 064/100 | Batch 000/469 | Gen/Dis Loss: 0.8696/0.6542
# Epoch: 064/100 | Batch 100/469 | Gen/Dis Loss: 0.7462/0.6566
# Epoch: 064/100 | Batch 200/469 | Gen/Dis Loss: 0.8369/0.6345
# Epoch: 064/100 | Batch 300/469 | Gen/Dis Loss: 0.8143/0.6352
# Epoch: 064/100 | Batch 400/469 | Gen/Dis Loss: 0.8147/0.6203
# Time elapsed: 11.50 min
# Epoch: 065/100 | Batch 000/469 | Gen/Dis Loss: 0.8789/0.6210
# Epoch: 065/100 | Batch 100/469 | Gen/Dis Loss: 0.7476/0.6433
# Epoch: 065/100 | Batch 200/469 | Gen/Dis Loss: 1.0151/0.6116
# Epoch: 065/100 | Batch 300/469 | Gen/Dis Loss: 0.8576/0.6381
# Epoch: 065/100 | Batch 400/469 | Gen/Dis Loss: 0.7410/0.6575
# Time elapsed: 11.68 min
# Epoch: 066/100 | Batch 000/469 | Gen/Dis Loss: 0.9197/0.6112
# Epoch: 066/100 | Batch 100/469 | Gen/Dis Loss: 0.8118/0.6479
# Epoch: 066/100 | Batch 200/469 | Gen/Dis Loss: 0.7938/0.6362
# Epoch: 066/100 | Batch 300/469 | Gen/Dis Loss: 0.9110/0.6206
# Epoch: 066/100 | Batch 400/469 | Gen/Dis Loss: 0.7662/0.6489
# Time elapsed: 11.87 min
# Epoch: 067/100 | Batch 000/469 | Gen/Dis Loss: 0.8390/0.6178
# Epoch: 067/100 | Batch 100/469 | Gen/Dis Loss: 0.8750/0.5938
# Epoch: 067/100 | Batch 200/469 | Gen/Dis Loss: 0.8152/0.6410
# Epoch: 067/100 | Batch 300/469 | Gen/Dis Loss: 1.0365/0.6078
# Epoch: 067/100 | Batch 400/469 | Gen/Dis Loss: 0.8215/0.6410
# Time elapsed: 12.07 min
# Epoch: 068/100 | Batch 000/469 | Gen/Dis Loss: 1.0783/0.6167
# Epoch: 068/100 | Batch 100/469 | Gen/Dis Loss: 0.9167/0.6287
# Epoch: 068/100 | Batch 200/469 | Gen/Dis Loss: 0.8265/0.6642
# Epoch: 068/100 | Batch 300/469 | Gen/Dis Loss: 0.8603/0.6618
# Epoch: 068/100 | Batch 400/469 | Gen/Dis Loss: 0.9167/0.6044
# Time elapsed: 12.25 min
# Epoch: 069/100 | Batch 000/469 | Gen/Dis Loss: 0.8821/0.5926
# Epoch: 069/100 | Batch 100/469 | Gen/Dis Loss: 1.0851/0.6160
# Epoch: 069/100 | Batch 200/469 | Gen/Dis Loss: 0.8775/0.6058
# Epoch: 069/100 | Batch 300/469 | Gen/Dis Loss: 0.9023/0.6393
# Epoch: 069/100 | Batch 400/469 | Gen/Dis Loss: 0.9080/0.6192
# Time elapsed: 12.44 min
# Epoch: 070/100 | Batch 000/469 | Gen/Dis Loss: 0.8675/0.6494
# Epoch: 070/100 | Batch 100/469 | Gen/Dis Loss: 0.8134/0.6800
# Epoch: 070/100 | Batch 200/469 | Gen/Dis Loss: 1.1381/0.6116
# Epoch: 070/100 | Batch 300/469 | Gen/Dis Loss: 1.0123/0.6323
# Epoch: 070/100 | Batch 400/469 | Gen/Dis Loss: 0.8059/0.6757
# Time elapsed: 12.63 min
# Epoch: 071/100 | Batch 000/469 | Gen/Dis Loss: 0.9558/0.6498
# Epoch: 071/100 | Batch 100/469 | Gen/Dis Loss: 0.8477/0.6374
# Epoch: 071/100 | Batch 200/469 | Gen/Dis Loss: 1.0860/0.5930
# Epoch: 071/100 | Batch 300/469 | Gen/Dis Loss: 0.9885/0.6727
# Epoch: 071/100 | Batch 400/469 | Gen/Dis Loss: 0.8330/0.6108
# Time elapsed: 12.82 min
# Epoch: 072/100 | Batch 000/469 | Gen/Dis Loss: 0.8829/0.6423
# Epoch: 072/100 | Batch 100/469 | Gen/Dis Loss: 0.7906/0.6475
# Epoch: 072/100 | Batch 200/469 | Gen/Dis Loss: 0.8202/0.6498
# Epoch: 072/100 | Batch 300/469 | Gen/Dis Loss: 0.8325/0.6584
# Epoch: 072/100 | Batch 400/469 | Gen/Dis Loss: 0.7649/0.6572
# Time elapsed: 13.00 min
# Epoch: 073/100 | Batch 000/469 | Gen/Dis Loss: 0.8156/0.6180
# Epoch: 073/100 | Batch 100/469 | Gen/Dis Loss: 0.8815/0.6527
# Epoch: 073/100 | Batch 200/469 | Gen/Dis Loss: 1.0106/0.6320
# Epoch: 073/100 | Batch 300/469 | Gen/Dis Loss: 0.8791/0.6357
# Epoch: 073/100 | Batch 400/469 | Gen/Dis Loss: 0.8536/0.6332
# Time elapsed: 13.19 min
# Epoch: 074/100 | Batch 000/469 | Gen/Dis Loss: 0.9699/0.6041
# Epoch: 074/100 | Batch 100/469 | Gen/Dis Loss: 0.9159/0.6678
# Epoch: 074/100 | Batch 200/469 | Gen/Dis Loss: 1.0643/0.6429
# Epoch: 074/100 | Batch 300/469 | Gen/Dis Loss: 0.8594/0.6220
# Epoch: 074/100 | Batch 400/469 | Gen/Dis Loss: 0.8424/0.6288
# Time elapsed: 13.39 min
# Epoch: 075/100 | Batch 000/469 | Gen/Dis Loss: 0.8658/0.6413
# Epoch: 075/100 | Batch 100/469 | Gen/Dis Loss: 1.0251/0.6595
# Epoch: 075/100 | Batch 200/469 | Gen/Dis Loss: 0.8430/0.6227
# Epoch: 075/100 | Batch 300/469 | Gen/Dis Loss: 0.8763/0.5991
# Epoch: 075/100 | Batch 400/469 | Gen/Dis Loss: 1.0922/0.5878
# Time elapsed: 13.58 min
# Epoch: 076/100 | Batch 000/469 | Gen/Dis Loss: 0.8047/0.6429
# Epoch: 076/100 | Batch 100/469 | Gen/Dis Loss: 0.8786/0.6222
# Epoch: 076/100 | Batch 200/469 | Gen/Dis Loss: 0.7790/0.6278
# Epoch: 076/100 | Batch 300/469 | Gen/Dis Loss: 0.8673/0.6372
# Epoch: 076/100 | Batch 400/469 | Gen/Dis Loss: 0.9143/0.6831
# Time elapsed: 13.77 min
# Epoch: 077/100 | Batch 000/469 | Gen/Dis Loss: 1.0119/0.6017
# Epoch: 077/100 | Batch 100/469 | Gen/Dis Loss: 0.8325/0.6391
# Epoch: 077/100 | Batch 200/469 | Gen/Dis Loss: 0.8205/0.6093
# Epoch: 077/100 | Batch 300/469 | Gen/Dis Loss: 0.8760/0.6380
# Epoch: 077/100 | Batch 400/469 | Gen/Dis Loss: 0.7481/0.6624
# Time elapsed: 13.95 min
# Epoch: 078/100 | Batch 000/469 | Gen/Dis Loss: 0.8270/0.6439
# Epoch: 078/100 | Batch 100/469 | Gen/Dis Loss: 0.8221/0.6412
# Epoch: 078/100 | Batch 200/469 | Gen/Dis Loss: 0.7881/0.6038
# Epoch: 078/100 | Batch 300/469 | Gen/Dis Loss: 0.8489/0.6294
# Epoch: 078/100 | Batch 400/469 | Gen/Dis Loss: 0.7494/0.7001
# Time elapsed: 14.14 min
# Epoch: 079/100 | Batch 000/469 | Gen/Dis Loss: 0.8274/0.6880
# Epoch: 079/100 | Batch 100/469 | Gen/Dis Loss: 0.9454/0.6092
# Epoch: 079/100 | Batch 200/469 | Gen/Dis Loss: 0.8618/0.6225
# Epoch: 079/100 | Batch 300/469 | Gen/Dis Loss: 1.0005/0.6677
# Epoch: 079/100 | Batch 400/469 | Gen/Dis Loss: 0.8457/0.6527
# Time elapsed: 14.33 min
# Epoch: 080/100 | Batch 000/469 | Gen/Dis Loss: 1.3355/0.6415
# Epoch: 080/100 | Batch 100/469 | Gen/Dis Loss: 0.9892/0.6661
# Epoch: 080/100 | Batch 200/469 | Gen/Dis Loss: 0.7567/0.6580
# Epoch: 080/100 | Batch 300/469 | Gen/Dis Loss: 0.8183/0.6285
# Epoch: 080/100 | Batch 400/469 | Gen/Dis Loss: 1.0033/0.6162
# Time elapsed: 14.52 min
# Epoch: 081/100 | Batch 000/469 | Gen/Dis Loss: 0.8488/0.6290
# Epoch: 081/100 | Batch 100/469 | Gen/Dis Loss: 0.8312/0.6396
# Epoch: 081/100 | Batch 200/469 | Gen/Dis Loss: 0.9317/0.6280
# Epoch: 081/100 | Batch 300/469 | Gen/Dis Loss: 0.8627/0.6339
# Epoch: 081/100 | Batch 400/469 | Gen/Dis Loss: 0.9765/0.6604
# Time elapsed: 14.71 min
# Epoch: 082/100 | Batch 000/469 | Gen/Dis Loss: 0.8387/0.6296
# Epoch: 082/100 | Batch 100/469 | Gen/Dis Loss: 0.8787/0.6139
# Epoch: 082/100 | Batch 200/469 | Gen/Dis Loss: 0.8280/0.6220
# Epoch: 082/100 | Batch 300/469 | Gen/Dis Loss: 0.8986/0.6398
# Epoch: 082/100 | Batch 400/469 | Gen/Dis Loss: 0.9048/0.5802
# Time elapsed: 14.90 min
# Epoch: 083/100 | Batch 000/469 | Gen/Dis Loss: 0.8626/0.6080
# Epoch: 083/100 | Batch 100/469 | Gen/Dis Loss: 1.0238/0.6294
# Epoch: 083/100 | Batch 200/469 | Gen/Dis Loss: 0.9284/0.6149
# Epoch: 083/100 | Batch 300/469 | Gen/Dis Loss: 0.9062/0.6507
# Epoch: 083/100 | Batch 400/469 | Gen/Dis Loss: 0.8747/0.6336
# Time elapsed: 15.09 min
# Epoch: 084/100 | Batch 000/469 | Gen/Dis Loss: 0.8313/0.6175
# Epoch: 084/100 | Batch 100/469 | Gen/Dis Loss: 0.8945/0.6564
# Epoch: 084/100 | Batch 200/469 | Gen/Dis Loss: 0.8541/0.6180
# Epoch: 084/100 | Batch 300/469 | Gen/Dis Loss: 0.8019/0.6467
# Epoch: 084/100 | Batch 400/469 | Gen/Dis Loss: 0.8468/0.6366
# Time elapsed: 15.27 min
# Epoch: 085/100 | Batch 000/469 | Gen/Dis Loss: 0.8562/0.6441
# Epoch: 085/100 | Batch 100/469 | Gen/Dis Loss: 0.8785/0.6318
# Epoch: 085/100 | Batch 200/469 | Gen/Dis Loss: 0.8666/0.6426
# Epoch: 085/100 | Batch 300/469 | Gen/Dis Loss: 0.8827/0.6469
# Epoch: 085/100 | Batch 400/469 | Gen/Dis Loss: 0.9627/0.6159
# Time elapsed: 15.46 min
# Epoch: 086/100 | Batch 000/469 | Gen/Dis Loss: 0.8190/0.6353
# Epoch: 086/100 | Batch 100/469 | Gen/Dis Loss: 0.7438/0.6261
# Epoch: 086/100 | Batch 200/469 | Gen/Dis Loss: 0.8428/0.6203
# Epoch: 086/100 | Batch 300/469 | Gen/Dis Loss: 0.8583/0.6136
# Epoch: 086/100 | Batch 400/469 | Gen/Dis Loss: 0.8312/0.6406
# Time elapsed: 15.65 min
# Epoch: 087/100 | Batch 000/469 | Gen/Dis Loss: 0.8389/0.6510
# Epoch: 087/100 | Batch 100/469 | Gen/Dis Loss: 0.8340/0.6473
# Epoch: 087/100 | Batch 200/469 | Gen/Dis Loss: 0.7540/0.6465
# Epoch: 087/100 | Batch 300/469 | Gen/Dis Loss: 0.7722/0.6484
# Epoch: 087/100 | Batch 400/469 | Gen/Dis Loss: 0.8525/0.6438
# Time elapsed: 15.83 min
# Epoch: 088/100 | Batch 000/469 | Gen/Dis Loss: 0.8000/0.6425
# Epoch: 088/100 | Batch 100/469 | Gen/Dis Loss: 0.7343/0.6478
# Epoch: 088/100 | Batch 200/469 | Gen/Dis Loss: 0.8431/0.6272
# Epoch: 088/100 | Batch 300/469 | Gen/Dis Loss: 0.8673/0.6242
# Epoch: 088/100 | Batch 400/469 | Gen/Dis Loss: 0.7177/0.6292
# Time elapsed: 16.01 min
# Epoch: 089/100 | Batch 000/469 | Gen/Dis Loss: 1.1865/0.5949
# Epoch: 089/100 | Batch 100/469 | Gen/Dis Loss: 0.8217/0.6683
# Epoch: 089/100 | Batch 200/469 | Gen/Dis Loss: 0.8207/0.6470
# Epoch: 089/100 | Batch 300/469 | Gen/Dis Loss: 0.8159/0.6101
# Epoch: 089/100 | Batch 400/469 | Gen/Dis Loss: 0.8392/0.6556
# Time elapsed: 16.20 min
# Epoch: 090/100 | Batch 000/469 | Gen/Dis Loss: 0.8213/0.6468
# Epoch: 090/100 | Batch 100/469 | Gen/Dis Loss: 0.8616/0.6489
# Epoch: 090/100 | Batch 200/469 | Gen/Dis Loss: 0.8192/0.6343
# Epoch: 090/100 | Batch 300/469 | Gen/Dis Loss: 0.7875/0.6304
# Epoch: 090/100 | Batch 400/469 | Gen/Dis Loss: 0.9931/0.6423
# Time elapsed: 16.39 min
# Epoch: 091/100 | Batch 000/469 | Gen/Dis Loss: 0.9952/0.6063
# Epoch: 091/100 | Batch 100/469 | Gen/Dis Loss: 0.8545/0.6208
# Epoch: 091/100 | Batch 200/469 | Gen/Dis Loss: 0.7092/0.6640
# Epoch: 091/100 | Batch 300/469 | Gen/Dis Loss: 0.8073/0.6408
# Epoch: 091/100 | Batch 400/469 | Gen/Dis Loss: 0.8120/0.6153
# Time elapsed: 16.57 min
# Epoch: 092/100 | Batch 000/469 | Gen/Dis Loss: 0.7907/0.6544
# Epoch: 092/100 | Batch 100/469 | Gen/Dis Loss: 0.8132/0.6270
# Epoch: 092/100 | Batch 200/469 | Gen/Dis Loss: 0.8991/0.6325
# Epoch: 092/100 | Batch 300/469 | Gen/Dis Loss: 0.8088/0.6274
# Epoch: 092/100 | Batch 400/469 | Gen/Dis Loss: 0.8507/0.6109
# Time elapsed: 16.75 min
# Epoch: 093/100 | Batch 000/469 | Gen/Dis Loss: 0.9306/0.6388
# Epoch: 093/100 | Batch 100/469 | Gen/Dis Loss: 0.9997/0.6337
# Epoch: 093/100 | Batch 200/469 | Gen/Dis Loss: 0.8000/0.6780
# Epoch: 093/100 | Batch 300/469 | Gen/Dis Loss: 0.8187/0.6119
# Epoch: 093/100 | Batch 400/469 | Gen/Dis Loss: 0.8489/0.6013
# Time elapsed: 16.94 min
# Epoch: 094/100 | Batch 000/469 | Gen/Dis Loss: 0.9654/0.6502
# Epoch: 094/100 | Batch 100/469 | Gen/Dis Loss: 0.7726/0.6563
# Epoch: 094/100 | Batch 200/469 | Gen/Dis Loss: 0.8410/0.6312
# Epoch: 094/100 | Batch 300/469 | Gen/Dis Loss: 0.8591/0.6141
# Epoch: 094/100 | Batch 400/469 | Gen/Dis Loss: 0.8165/0.6038
# Time elapsed: 17.13 min
# Epoch: 095/100 | Batch 000/469 | Gen/Dis Loss: 0.7965/0.6140
# Epoch: 095/100 | Batch 100/469 | Gen/Dis Loss: 0.9572/0.6584
# Epoch: 095/100 | Batch 200/469 | Gen/Dis Loss: 0.9146/0.6753
# Epoch: 095/100 | Batch 300/469 | Gen/Dis Loss: 0.8424/0.6457
# Epoch: 095/100 | Batch 400/469 | Gen/Dis Loss: 1.1917/0.6243
# Time elapsed: 17.31 min
# Epoch: 096/100 | Batch 000/469 | Gen/Dis Loss: 0.9016/0.6179
# Epoch: 096/100 | Batch 100/469 | Gen/Dis Loss: 0.8466/0.6188
# Epoch: 096/100 | Batch 200/469 | Gen/Dis Loss: 0.8740/0.6295
# Epoch: 096/100 | Batch 300/469 | Gen/Dis Loss: 0.8982/0.6375
# Epoch: 096/100 | Batch 400/469 | Gen/Dis Loss: 0.9716/0.5934
# Time elapsed: 17.50 min
# Epoch: 097/100 | Batch 000/469 | Gen/Dis Loss: 0.8770/0.6367
# Epoch: 097/100 | Batch 100/469 | Gen/Dis Loss: 0.9119/0.6232
# Epoch: 097/100 | Batch 200/469 | Gen/Dis Loss: 0.8138/0.6309
# Epoch: 097/100 | Batch 300/469 | Gen/Dis Loss: 0.7702/0.6408
# Epoch: 097/100 | Batch 400/469 | Gen/Dis Loss: 0.8503/0.6383
# Time elapsed: 17.69 min
# Epoch: 098/100 | Batch 000/469 | Gen/Dis Loss: 0.7995/0.6689
# Epoch: 098/100 | Batch 100/469 | Gen/Dis Loss: 0.8405/0.6268
# Epoch: 098/100 | Batch 200/469 | Gen/Dis Loss: 0.8864/0.6400
# Epoch: 098/100 | Batch 300/469 | Gen/Dis Loss: 1.1815/0.6208
# Epoch: 098/100 | Batch 400/469 | Gen/Dis Loss: 0.6848/0.6863
# Time elapsed: 17.87 min
# Epoch: 099/100 | Batch 000/469 | Gen/Dis Loss: 0.8594/0.6176
# Epoch: 099/100 | Batch 100/469 | Gen/Dis Loss: 0.8191/0.6477
# Epoch: 099/100 | Batch 200/469 | Gen/Dis Loss: 0.9846/0.6349
# Epoch: 099/100 | Batch 300/469 | Gen/Dis Loss: 0.8413/0.6397
# Epoch: 099/100 | Batch 400/469 | Gen/Dis Loss: 0.8228/0.6392
# Time elapsed: 18.06 min
# Epoch: 100/100 | Batch 000/469 | Gen/Dis Loss: 0.8914/0.6126
# Epoch: 100/100 | Batch 100/469 | Gen/Dis Loss: 0.9035/0.6191
# Epoch: 100/100 | Batch 200/469 | Gen/Dis Loss: 0.7584/0.6548
# Epoch: 100/100 | Batch 300/469 | Gen/Dis Loss: 0.9125/0.6687
# Epoch: 100/100 | Batch 400/469 | Gen/Dis Loss: 1.0086/0.6310
# Time elapsed: 18.24 min
# Total Training Time: 18.24 min

# %% [markdown]
# ## Evaluation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(gener_costs)), gener_costs, label='generator loss')
plt.plot(range(len(discr_costs)), discr_costs, label='discriminator loss')
plt.legend()
plt.show()

# %%
##########################
### VISUALIZATION
##########################


model.eval()
# Make new images
z = torch.zeros((5, LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
generated_features = model.generator_forward(z)
imgs = generated_features.view(-1, 28, 28)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 2.5))


for i, ax in enumerate(axes):
    axes[i].imshow(imgs[i].to(torch.device('cpu')).detach(), cmap='binary')
